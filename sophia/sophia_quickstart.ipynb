# %%
import pandas as pd
import numpy as np

# %%
raw_loc = '/data/repos/galaxy-zoo-panoptes/reduction/data/raw/classifications/2018-03-19_panoptes-classifications.csv'

# %%
df = pd.read_csv(raw_loc, nrows=1000, dtype={'user_id': str})

# %%
df.to_csv('raw_galaxy-zoo_1k_rows.csv')

# %%
df.head()
# Out:
#    classification_id      user_name  user_id               user_ip  \
# 0           80259843      klmasters       54  dffe3df810a788a70d17
# 1           80261296          cmk24      108  dffe3df810a788a70d17
# 2           80261403          cmk24      108  dffe3df810a788a70d17
# 3           80262513        tingard  1402338  dffe3df810a788a70d17
# 4           80340601  hughdickinson  1460166  ffcb405e549f2d6b4147
#
#    workflow_id    workflow_name  workflow_version               created_at  \
# 0         5528  DECals workflow            92.131  2017-11-29 15:41:11 UTC
# 1         5528  DECals workflow            92.131  2017-11-29 15:52:12 UTC
# 2         5528  DECals workflow            92.131  2017-11-29 15:53:00 UTC
# 3         5528  DECals workflow            92.138  2017-11-29 15:59:37 UTC
# 4         5528  DECals workflow            92.138  2017-11-29 21:34:32 UTC
#
#    gold_standard  expert                                           metadata  \
# ...

# %%
type(df['created_at'].iloc[0])
# Out:
# str

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

# %%
df[df['created_at'] < pd.to_datetime('2017-11-29')]
# Out:
#    classification_id  user_name user_id               user_ip  workflow_id  \
# 0           80259843  klmasters      54  dffe3df810a788a70d17         5528
# 1           80261296      cmk24     108  dffe3df810a788a70d17         5528
# 2           80261403      cmk24     108  dffe3df810a788a70d17         5528
#
#      workflow_name  workflow_version          created_at  gold_standard  \
# 0  DECals workflow            92.131 2017-11-29 15:41:11            NaN
# 1  DECals workflow            92.131 2017-11-29 15:52:12            NaN
# 2  DECals workflow            92.131 2017-11-29 15:53:00            NaN
#
#    expert                                           metadata  \
# 0     NaN  {"session":"bb659ea9091e361d4f44be0e1399b3863c...
# 1     NaN  {"session":"4401dda486c8ee5597eb2060e265feaf55...
# 2     NaN  {"session":"4401dda486c8ee5597eb2060e265feaf55...
#
#                                          annotations  \
# 0  [{"task":"T0","task_label":"Is the galaxy simp...
# ...

# %%
len(df[df['user_name']=='ElisabethB'])
# Out:
# 19

# %%
df['user_name']
# Out:
# 0                               klmasters
# 1                                   cmk24
# 2                                   cmk24
# 3                                 tingard
# 4                           hughdickinson
# 5                              ElisabethB
# 6                              ElisabethB
# 7                              ElisabethB
# 8                              ElisabethB
# 9                              ElisabethB
# 10                             ElisabethB
# 11                             ElisabethB
# 12                           MikeWalmsley
# 13                           MikeWalmsley
# 14                           MikeWalmsley
# 15                           MikeWalmsley
# 16                           MikeWalmsley
# 17                           MikeWalmsley
# 18                             ElisabethB
# 19                             ElisabethB
# 20                             ElisabethB
# 21                             ElisabethB
# ...

# %%
{'snorkey', 'Arnie52'} - {'snorkey'}
# Out:
# {'Arnie52'}

# %%
'hello'.capitalize()
# Out:
# 'Hello'

# %%
df[df['user_name'].isin(usernames)]
# Out:
#      classification_id user_name user_id               user_ip  workflow_id  \
# 474           88894001   Arnie52  711942  425e50e8b8a319e5817c         5653
# 482           88894050   Arnie52  711942  425e50e8b8a319e5817c         5653
# 495           88894183   Arnie52  711942  425e50e8b8a319e5817c         5653
# 506           88894283   Arnie52  711942  425e50e8b8a319e5817c         5653
# 517           88894335   Arnie52  711942  425e50e8b8a319e5817c         5653
# 521           88894369   Arnie52  711942  425e50e8b8a319e5817c         5653
# 537           88894462   Arnie52  711942  425e50e8b8a319e5817c         5653
# 572           88894780   Arnie52  711942  425e50e8b8a319e5817c         5653
# 586           88894898   Arnie52  711942  425e50e8b8a319e5817c         5653
# 600           88895029   Arnie52  711942  425e50e8b8a319e5817c         5653
# 615           88895191   Arnie52  711942  425e50e8b8a319e5817c         5653
# ...

# %%
df = df[~df['user_name'].str.startswith('not-logged-in')]

# %%
unique_names = df['user_name'].unique()

# %%
n_groups = 4

# %%
len(unique_names)
# Out:
# 91

# %%
group_size = len(unique_names) // n_groups

# %%
group_size
# Out:
# 22

# %%
df_shuffled = df.sample(len(df)).reset_index()

# %%
nums = np.arange(10)

# %%
nums[:3]
# Out:
# array([0, 1, 2])

# %%
groups = []
current_split = 0
for n in range(n_groups):
    new_split = current_split + group_size
    groups.append(unique_names[current_split:new_split])
    current_split = new_split

# %%
for group in groups:
    assert len(group) == group_size
    # TODO assert that groups are unique
# Out:
# ['klmasters' 'cmk24' 'tingard' 'hughdickinson' 'ElisabethB' 'MikeWalmsley'
#  'rjsmethurst' 'astopy' 'LucyitSwD' 'mrniaboc' 'HaWe' 'haskielr'
#  'BedfordScience' 'starkindustries' 'mgts24' 'pistaccio' 'ismail_faziz'
#  'joncarruthers' 'hermesp' 'PeterBayliss' 'mistely' 'JaroslavMerc']
# ['ryand05' 'gklueh' 'buttie' 'bhlewis' 'castles1' 'MacMike' 'nancypants'
#  'nen3d' 'karthikeyan.d' 'TeachEarthSpace' 'Ogrady859' 'haraldernst'
#  'Malina-B' 'kfernet' 'Bexleygirl00' 'LonMcGregor' 'LisaV' 'Aza'
#  'msn26586' 'ferre' 'roybe1' 'Arnie52']
# ['ragnartrains' 'anncapcp.com' 'tomhopper' 'bowe' 'Molco' 'katiefanch'
#  'Bluecharm7' 'KlaraMaria' 'Mars56' 'exebandit' 'Skyletron' 'helloboo'
#  'rustypowell' 'dksteele75' 'mschatte' 'Ehlyah' 'KirkRSimpson' 'pontifex'
#  'lightyear105' 'Astro_Denny' 'MerylPG' 'gpwomack']
# ['creative-i' 'Giraffes' 'meteorologyman' 'rob_t' 'snorkey'
#  'stevewanstall' 'amartineau' 'boubo' 'andywing' 'CometGirl2' 'zpace21'
# ...

# %%
groups_df = pd.DataFrame(data={
    'group_a': groups[0],
    'group_b': groups[1],
    'group_c': groups[2],
    'group_d': groups[3]
})
groups_df
# Out:
#             group_a          group_b       group_c         group_d
# 0         klmasters          ryand05  ragnartrains      creative-i
# 1             cmk24           gklueh  anncapcp.com        Giraffes
# 2           tingard           buttie     tomhopper  meteorologyman
# 3     hughdickinson          bhlewis          bowe           rob_t
# 4        ElisabethB         castles1         Molco         snorkey
# 5      MikeWalmsley          MacMike    katiefanch   stevewanstall
# 6       rjsmethurst       nancypants    Bluecharm7      amartineau
# 7            astopy            nen3d    KlaraMaria           boubo
# 8         LucyitSwD    karthikeyan.d        Mars56        andywing
# 9          mrniaboc  TeachEarthSpace     exebandit      CometGirl2
# 10             HaWe        Ogrady859     Skyletron         zpace21
# 11         haskielr      haraldernst      helloboo      LorinLumps
# 12   BedfordScience         Malina-B   rustypowell       tjnelson5
# ...

# %%
groups_df.to_csv('groups.csv', index=False)

# %%
pd.read_csv('groups.csv')
# Out:
#             group_a          group_b       group_c         group_d
# 0         klmasters          ryand05  ragnartrains      creative-i
# 1             cmk24           gklueh  anncapcp.com        Giraffes
# 2           tingard           buttie     tomhopper  meteorologyman
# 3     hughdickinson          bhlewis          bowe           rob_t
# 4        ElisabethB         castles1         Molco         snorkey
# 5      MikeWalmsley          MacMike    katiefanch   stevewanstall
# 6       rjsmethurst       nancypants    Bluecharm7      amartineau
# 7            astopy            nen3d    KlaraMaria           boubo
# 8         LucyitSwD    karthikeyan.d        Mars56        andywing
# 9          mrniaboc  TeachEarthSpace     exebandit      CometGirl2
# 10             HaWe        Ogrady859     Skyletron         zpace21
# 11         haskielr      haraldernst      helloboo      LorinLumps
# 12   BedfordScience         Malina-B   rustypowell       tjnelson5
# ...
